# %%
#Diana Yuhua, 8-936-481
#Jacky He, 3-740-114
#Dennis Fong, 3-740-2
#Xueya Xie, E-8-172672

# %%
# 
# !pip install dnspython
# !pip install pymongo
# !pip install pymongo[srv]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 269 kB 4.8 MB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#Establecer la conexión y verificar el server conectado, importar todas las librerías
import datetime
import pprint
import csv
import json
import pandas as pd
from pymongo import MongoClient
uri = "mongodb+srv://xiexueya:tarea2@cluster0.ydncmm3.mongodb.net/?retryWrites=true&w=majority"
client = MongoClient( uri )
print(client)

#Se crea el base de datos en MongoDB
db=client.covid
print(db)
# Out:
# MongoClient(host=['ac-wq9eran-shard-00-00.ydncmm3.mongodb.net:27017', 'ac-wq9eran-shard-00-02.ydncmm3.mongodb.net:27017', 'ac-wq9eran-shard-00-01.ydncmm3.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-1x99hj-shard-0', tls=True)
# Database(MongoClient(host=['ac-wq9eran-shard-00-00.ydncmm3.mongodb.net:27017', 'ac-wq9eran-shard-00-02.ydncmm3.mongodb.net:27017', 'ac-wq9eran-shard-00-01.ydncmm3.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-1x99hj-shard-0', tls=True), 'covid')

# %%
#Crear la coleccion
casos=db['casos_de_covid']
print(casos)
pp=pprint.PrettyPrinter(indent=2)
# Out:
# Collection(Database(MongoClient(host=['ac-wq9eran-shard-00-00.ydncmm3.mongodb.net:27017', 'ac-wq9eran-shard-00-02.ydncmm3.mongodb.net:27017', 'ac-wq9eran-shard-00-01.ydncmm3.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-1x99hj-shard-0', tls=True), 'covid'), 'casos_de_covid')

# %%
# Leer el archivo csv como una de las listas
with open('casos.csv', 'r') as read_obj:
    # Pasar el objeto archivo a reader()
    csv_reader = csv.DictReader(read_obj)
    # Conseguir la lista
    mylist = list(csv_reader)
    x = casos.insert_many(mylist)

    #Imprime los ids
    print(x.inserted_ids)
# Out:
# [ObjectId('62a2dab4865d22ee9d3dd325'), ObjectId('62a2dab4865d22ee9d3dd326'), ObjectId('62a2dab4865d22ee9d3dd327'), ObjectId('62a2dab4865d22ee9d3dd328'), ObjectId('62a2dab4865d22ee9d3dd329'), ObjectId('62a2dab4865d22ee9d3dd32a'), ObjectId('62a2dab4865d22ee9d3dd32b'), ObjectId('62a2dab4865d22ee9d3dd32c'), ObjectId('62a2dab4865d22ee9d3dd32d'), ObjectId('62a2dab4865d22ee9d3dd32e'), ObjectId('62a2dab4865d22ee9d3dd32f'), ObjectId('62a2dab4865d22ee9d3dd330'), ObjectId('62a2dab4865d22ee9d3dd331'), ObjectId('62a2dab4865d22ee9d3dd332'), ObjectId('62a2dab4865d22ee9d3dd333'), ObjectId('62a2dab4865d22ee9d3dd334'), ObjectId('62a2dab4865d22ee9d3dd335'), ObjectId('62a2dab4865d22ee9d3dd336'), ObjectId('62a2dab4865d22ee9d3dd337'), ObjectId('62a2dab4865d22ee9d3dd338'), ObjectId('62a2dab4865d22ee9d3dd339'), ObjectId('62a2dab4865d22ee9d3dd33a'), ObjectId('62a2dab4865d22ee9d3dd33b'), ObjectId('62a2dab4865d22ee9d3dd33c'), ObjectId('62a2dab4865d22ee9d3dd33d'), ObjectId('62a2dab4865d22ee9d3dd33e'), ObjectId(
# ...

# %%
#Imprimirlas para comprobar han sido insertados
pp=pprint.PrettyPrinter(indent=2)  
pp.pprint(list ( casos.find() ))
# Out:
# [ { '_id': ObjectId('62a2dab4865d22ee9d3dd325'),
#     'casos': '303',
#     'corregimientos': 'Puerto Almirante',
#     'distrito': 'Almirante',
#     'sede del distrito': 'Puerto Almirante',
#     '\ufeffprovincia': 'Bocas del Toro'},
#   { '_id': ObjectId('62a2dab4865d22ee9d3dd326'),
#     'casos': '386',
#     'corregimientos': 'Barriada Guaymí',
#     'distrito': 'Almirante',
#     'sede del distrito': 'Puerto Almirante',
#     '\ufeffprovincia': 'Bocas del Toro'},
#   { '_id': ObjectId('62a2dab4865d22ee9d3dd327'),
#     'casos': '104',
#     'corregimientos': 'Barrio Francés',
#     'distrito': 'Almirante',
#     'sede del distrito': 'Puerto Almirante',
#     '\ufeffprovincia': 'Bocas del Toro'},
#   { '_id': ObjectId('62a2dab4865d22ee9d3dd328'),
#     'casos': '189',
#     'corregimientos': 'Nance de Risco',
#     'distrito': 'Almirante',
#     'sede del distrito': 'Puerto Almirante',
#     '\ufeffprovincia': 'Bocas del Toro'},
# ...
